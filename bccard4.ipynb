# %%
import pandas as pd

card1 = pd.read_csv('C:\\Users\\sjjung\\Desktop\\mid_portfolio\\files\\card1.csv',encoding='euckr')
card1
card2 = pd.read_csv('C:\\Users\\sjjung\\Desktop\\mid_portfolio\\files\\card2.csv',encoding='euckr')
card2
# Out:
#      카드사명      수     비중
# 0    비씨카드    364  42.72
# 1    삼성카드  1,126   7.58
# 2    신한카드  1,154   5.77
# 3    현대카드  1,268   8.05
# 4  KB국민카드  1,442   9.50

# %%
# 라이브러리
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import warnings
# %matplotlib inline

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname = 'C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family = font_name)

plt.style.use('seaborn') # seaborn 스타일로 변환
plt.rc('font',family='Malgun Gothic')
plt.rc('axes',unicode_minus=False)
pd.set_option('display.max_columns',None)
warnings.filterwarnings(action='ignore') # Warning Message 안 보이게
import pandas.util.testing as tm

import matplotlib as mpl # 고해상도 Plot 을 위해 DPI 조절
mpl.rcParams['figure.dpi']=150

# %%
colors = [ 'Red', 'Blue', 'skyBlue', 'Green', 'Orange']

fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

#ax1.bar(card1.카드사명,card1.수,label='단위 : 천 매')
ax1.bar(card1.카드사명,card1.비중,color=colors,label='단위 : %')

#ax2.bar(card2.카드사명,card2.수,label='단위 : 천 매')
ax2.bar(card2.카드사명,card2.비중,color=colors,label='단위 : %')

ax1.set_title('휴면신용카드 비중_21년 1분기')
ax2.set_title('휴면신용카드 비중_21년 2분기')

ax1.legend()
ax2.legend()

plt.show()
plt.savefig("stopped_card.png")
